# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd

df = pd.read_json('combined_pivoted.json', orient='columns')
df.head()
# Out:
#        STATION  DATE LATITUDE LONGITUDE ELEVATION       NAME CDSD  \
# 0  ASN00037120  1993 -21.8958  143.0967     220.0  WYORA, AS   24
# 1  ASN00037120  1994 -21.8958  143.0967     220.0  WYORA, AS    9
# 2  ASN00037120  1995 -21.8958  143.0967     220.0  WYORA, AS   19
# 3  ASN00037120  1996 -21.8958  143.0967     220.0  WYORA, AS   21
# 4  ASN00037120  1997 -21.8958  143.0967     220.0  WYORA, AS   25
#
#   CDSD_ATTRIBUTES CLDD CLDD_ATTRIBUTES  ... PRCP_ATTRIBUTES  SNOW  \
# 0               a   20               a  ...            None  None
# 1               a    9               a  ...            None  None
# 2               a   18               a  ...            None  None
# 3               a   21               a  ...            None  None
# 4               a   21               a  ...            None  None
#
#   SNOW_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN  \
# 0            None  None            None  None            None  None
# 1            None  None            None  None            None  None
# 2            None  None            None  None            None  None
# 3            None  None            None  None            None  None
# 4            None  None            None  None            None  None
#
#   TMIN_ATTRIBUTES  None
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
#
# [5 rows x 53 columns]
